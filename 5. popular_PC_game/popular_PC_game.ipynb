# %% [markdown]
# <h1>Содержание проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Открытие-файла-с-данными-и-изучение-общей-информации" data-toc-modified-id="Шаг-1.-Открытие-файла-с-данными-и-изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Открытие файла с данными и изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-шагу-1" data-toc-modified-id="Выводы-по-шагу-1-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выводы по шагу 1</a></span></li></ul></li><li><span><a href="#Шаг-2.-Подготовка-данных" data-toc-modified-id="Шаг-2.-Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Корректировка-названий-столбцов---приведение-к-нижнему-регистру." data-toc-modified-id="Корректировка-названий-столбцов---приведение-к-нижнему-регистру.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Корректировка названий столбцов - приведение к нижнему регистру.</a></span></li><li><span><a href="#Преобразование-типов-данных." data-toc-modified-id="Преобразование-типов-данных.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Преобразование типов данных.</a></span></li><li><span><a href="#Обработка-пропусков." data-toc-modified-id="Обработка-пропусков.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка пропусков.</a></span></li><li><span><a href="#Суммарные-продажи-по-всем-регионам." data-toc-modified-id="Суммарные-продажи-по-всем-регионам.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Суммарные продажи по всем регионам.</a></span></li><li><span><a href="#Выводы-по-шагу-2" data-toc-modified-id="Выводы-по-шагу-2-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы по шагу 2</a></span></li></ul></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сколько-игр-выпускалось-в-разные-годы." data-toc-modified-id="Сколько-игр-выпускалось-в-разные-годы.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сколько игр выпускалось в разные годы.</a></span></li><li><span><a href="#Изменение-продаж-по-платформам.-Платформы-с-наибольшими-суммарными-продажами.-Сроки-развития-новых-и-исчезновения-старых-платформ." data-toc-modified-id="Изменение-продаж-по-платформам.-Платформы-с-наибольшими-суммарными-продажами.-Сроки-развития-новых-и-исчезновения-старых-платформ.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Изменение продаж по платформам. Платформы с наибольшими суммарными продажами. Сроки развития новых и исчезновения старых платформ.</a></span></li><li><span><a href="#Актуальный-период-анализа-платформ-для-построения-прогноза-на-следующий-год." data-toc-modified-id="Актуальный-период-анализа-платформ-для-построения-прогноза-на-следующий-год.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Актуальный период анализа платформ для построения прогноза на следующий год.</a></span></li><li><span><a href="#Фильтрация-данных-по-актуальному-периоду." data-toc-modified-id="Фильтрация-данных-по-актуальному-периоду.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Фильтрация данных по актуальному периоду.</a></span></li><li><span><a href="#Платформы,-лидирующие-по-продажам,-динамика-роста.--Потенциально-прибыльные-платформы." data-toc-modified-id="Платформы,-лидирующие-по-продажам,-динамика-роста.--Потенциально-прибыльные-платформы.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Платформы, лидирующие по продажам, динамика роста.  Потенциально прибыльные платформы.</a></span></li><li><span><a href="#График-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам." data-toc-modified-id="График-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>График «ящик с усами» по глобальным продажам игр в разбивке по платформам.</a></span></li><li><span><a href="#Влияние-на-продажи-внутри-одной-популярной-платформы-отзывов-пользователей-и-критиков." data-toc-modified-id="Влияние-на-продажи-внутри-одной-популярной-платформы-отзывов-пользователей-и-критиков.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков.</a></span></li><li><span><a href="#Влияние-отзывов-критиков-и-пользователей-на-продажи-игр-на-других-платформах." data-toc-modified-id="Влияние-отзывов-критиков-и-пользователей-на-продажи-игр-на-других-платформах.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Влияние отзывов критиков и пользователей на продажи игр на других платформах.</a></span></li><li><span><a href="#Cамые-прибыльные-жанры.-Жанры-с-высокими-и-низкими-продажами." data-toc-modified-id="Cамые-прибыльные-жанры.-Жанры-с-высокими-и-низкими-продажами.-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Cамые прибыльные жанры. Жанры с высокими и низкими продажами.</a></span></li><li><span><a href="#Выводы-по-шагу-3" data-toc-modified-id="Выводы-по-шагу-3-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Выводы по шагу 3</a></span></li></ul></li><li><span><a href="#Шаг-4.-Портрет-пользователя-каждого-региона" data-toc-modified-id="Шаг-4.-Портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-популярных-платформ.-Различия-в-долях-продаж." data-toc-modified-id="Топ-5-популярных-платформ.-Различия-в-долях-продаж.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Топ-5 популярных платформ. Различия в долях продаж.</a></span></li><li><span><a href="#Топ-5-популярных-жанров." data-toc-modified-id="Топ-5-популярных-жанров.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Топ-5 популярных жанров.</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе." data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в отдельном регионе.</a></span></li><li><span><a href="#Выводы-по-шагу-4" data-toc-modified-id="Выводы-по-шагу-4-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выводы по шагу 4</a></span></li></ul></li><li><span><a href="#Шаг-5.-Проверка-гипотез" data-toc-modified-id="Шаг-5.-Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 5. Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые." data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные</a></span></li><li><span><a href="#Выводы-по-шагу-5" data-toc-modified-id="Выводы-по-шагу-5-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Выводы по шагу 5</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # СБОРНЫЙ ПРОЕКТ - 1

# %% [markdown]
# **Описание исследования**
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# **Цель исследования**
#
# Выявить определяющие успешность игры закономерности для выбора потенциально популярного продукта и планирования рекламной кампании.

# %% [markdown]
# **Задачи исследования**
#
# Шаг 1. Открытие файла с данными и изучение общей информации
#
# Шаг 2. Подготовка данных
#
# Шаг 3. Проведение исследовательского анализа данных
#
# Шаг 4. Составление портрета пользователя каждого региона
#
# Шаг 5. Проверка гипотез
#
# Шаг 6. Общий вывод по исследованию

# %% [markdown]
# Содержание сделал в начале проекта.

# %% [markdown]
# ## Шаг 1. Открытие файла с данными и изучение общей информации

# %% [markdown]
# Подключим необходимые библиотеки:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
data = pd.read_csv('/datasets/games.csv')
data.info()
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# ...

# %% [markdown]
# ### Выводы по шагу 1
# Датафрейм состоит из 16715 строк и 11 столбцов с типами данных float64(6), object(5).

# %% [markdown]
# ## Шаг 2. Подготовка данных

# %% [markdown]
# Проверка на дубликаты:

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[data.duplicated(subset=['Name', 'Platform', 'Year_of_Release'])==True]
# Out:
#                 Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 14244            NaN      GEN           1993.0     NaN       0.0      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports       0.0      0.01
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 14244      0.03          0.0           NaN        NaN    NaN
# 16230      0.00          0.0          83.0        5.5      E

# %% [markdown]
# Строка 14244 имеет дубликат со строкой 659 - это два пропуска по столбцам name и genre. Она в дальнейшем все равно удалится - ее не трогаем. Вторая строка - явный дубликат!

# %%
data.query('Name=="Madden NFL 13" and Platform=="PS3"')
# Out:
#                 Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 604         0.0         0.23          83.0        5.5      E
# 16230       0.0         0.00          83.0        5.5      E

# %% [markdown]
# Причем по строке 16230 нет данных по продажам, поэтому удаляем ее

# %%
data = data.drop(index=16230)

# %% [markdown]
# ### Корректировка названий столбцов - приведение к нижнему регистру.

# %%
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Оценим процент одновременных пропусков по трем столбцам с рейтингом для каждой из платформ:

# %%
data1 = data['platform'].unique()
s = []
#s1 = []
for i in data1:
    s.append(len(data.query('platform==@i and critic_score.isna() and user_score.isna() \
    and rating.isna()')) / len(data.query('platform==@i')))
    #s1.append(len(data.query('platform==@i and critic_score.isna() and user_score.isna() \
    #and rating.isna()')) / 16713)
              
df = pd.DataFrame(s, index=data1) # процент наличия одновременных пропусков по платформам
df
# Out:
#              0
# Wii   0.237121
# NES   1.000000
# GB    1.000000
# DS    0.399814
# X360  0.159271
# PS3   0.272932
# PS2   0.313744
# SNES  1.000000
# GBA   0.364964
# PS4   0.318878
# 3DS   0.553846
# N64   1.000000
# PS    0.821220
# XB    0.105583
# PC    0.145791
# 2600  1.000000
# PSP   0.548387
# XOne  0.214575
# WiiU  0.285714
# GC    0.156475
# GEN   1.000000
# DC    0.730769
# PSV   0.646512
# SAT   1.000000
# SCD   1.000000
# WS    1.000000
# NG    1.000000
# TG16  1.000000
# 3DO   1.000000
# GG    1.000000
# PCFX  1.000000

# %%
len(data.query('platform== ["NES", "GB", "SNES", "N64", "2600", "GEN", "SAT",\
"SCD", "WS", "NG", "TG16", "3DO", "GG", "PCFX"]')) # доля одновременных пропусков по столбцам \
                                                    #critic_score, user_score, ratin
# Out:
# 1120

# %%
len(data.query('year_of_release<= 1994')) # число игр до 1994 включительно
# Out:
# 488

# %% [markdown]
# ### Преобразование типов данных.

# %% [markdown]
# Столбец year_of_release должен содержать целочисленные значения года выпуска, поэтому приведем его значения к типу int:

# %%
data['year_of_release'] = data['year_of_release'].astype('Int64')

# %% [markdown]
# **Столбцы name и genre** имеют по два общих пропуска, в базе недостаточно информации для их восстановления и они составляют малую часть от общей базы данных. Заполнять не будем.
#
# **Столбец year_of_release** имеет малый процент пропусков (1.6%), комментарии по их заполнению даны ниже. Но в общем случае заполнять нет смысла, так как они составляют малую часть от общей базы данных.
#
# **Пропуски по столбцам critic_score, user_score** можем заполнить с учетом информации из интернета путем парсинга какого-либо сайта. Из имеющихся в базе данных восстановить значения проблематично, поскольку оценка пользователей и критиков по одной и той же игре на разных платформах может сильно отличаться.
#
# **Пропуски в столбце rating** можем заполнить, если по интересуемой игре есть ее рейтинг на другой платформе или же парсить из интернета.
#
# Причины, которые могли привести к пропускам:
#
# столбцы name и genre - по 2 пропуска, похоже на человеческий фактор;
#
# столбец year_of_release - 269 пропусков, индексы пропусков идут вразнобой, человеческий фактор или программный сбой при считывании данных;
#
# столбцы critic_score, user_score, rating - пропусков очень много, причем за разные года. Скорее всего программный сбой при чтении данных из других БД (например, с рейтингом европейской или японской системы). Также возможно база данных подтягивала данные через сайты, у которых закончился хостинг.
#
# Часть платформ и без рейтинга, и без оценок - это платформы "NES", "GB", "SNES", "N64", "2600", "GEN", "SAT", "SCD", "WS", "NG", "TG16", "3DO", "GG", "PCFX", но они составляют лишь 1120/16713 = 6.7%. В основной массе - это старые платформы, которые существовали до рейтинга ESRB или на этапе его зарождения (1994), что является одной из причин наличия пропусков. Делать вывод, что наличие пропуска в одном столбце влияет на наличие пропуска в двух других наверно не стоит. Другие причины пропусков указал выше.
#
# Рейтинг ESRB не единственный, поэтому рейтинг по платформе может отсуствовать по причине использования другого рейтинга (европейский - PEGI , японский - CERO, российский - RARS, немецкий - USK и др.).

# %% [markdown]
# Столбцы na_sales, eu_sales, jp_sales, other_sales и critic_score записаны в млн. единиц. Перезапишем их значения в полном целочисленном виде:

# %%
data['na_sales'] = (data['na_sales'] * 1000000).astype(int)

# %%
data['eu_sales'] = (data['eu_sales'] * 1000000).astype(int)

# %%
data['jp_sales'] = (data['jp_sales'] * 1000000).astype(int)

# %%
data['other_sales'] = (data['other_sales'] * 1000000).astype(int)

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports  41360000
# 1         Super Mario Bros.      NES             1985      Platform  29080000
# 2            Mario Kart Wii      Wii             2008        Racing  15680000
# 3         Wii Sports Resort      Wii             2009        Sports  15610000
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  11270000
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0  28960000   3770000      8450000          76.0          8      E
# 1   3580000   6810000       770000           NaN        NaN    NaN
# 2  12760000   3790000      3290000          82.0        8.3      E
# 3  10930000   3280000      2950000          80.0          8      E
# 4   8890000  10220000      1000000           NaN        NaN    NaN

# %% [markdown]
# Столбец critic_score по условию содержит оценку критиков до 100, поэтому также преобразуем его значения в целочисленный тип данных с учетом, что есть значения типа nan:

# %%
data['critic_score'] = data['critic_score'].astype('Int64')

# %% [markdown]
# Столбец user_score имеет данные вещественного типа, но есть пропуски и значения 'tbd', поэтому пока менять тип не будем

# %% [markdown]
# Таким образом, датайфрейм будет выглядеть следующим образом:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16714 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16712 non-null  object
#  1   platform         16714 non-null  object
#  2   year_of_release  16445 non-null  Int64
#  3   genre            16712 non-null  object
#  4   na_sales         16714 non-null  int64
#  5   eu_sales         16714 non-null  int64
#  6   jp_sales         16714 non-null  int64
#  7   other_sales      16714 non-null  int64
#  8   critic_score     8136 non-null   Int64
#  9   user_score       10013 non-null  object
#  10  rating           9948 non-null   object
# dtypes: Int64(2), int64(4), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Обработка пропусков.

# %% [markdown]
# Смотрим количество пропусков в датафрейме:

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
data.isna().mean() #посчитаем доли пропусков
# Out:
# name               0.000120
# platform           0.000000
# year_of_release    0.016094
# genre              0.000120
# na_sales           0.000000
# eu_sales           0.000000
# jp_sales           0.000000
# other_sales        0.000000
# critic_score       0.513222
# user_score         0.400921
# rating             0.404810
# dtype: float64

# %% [markdown]
# **Пропуски в столбце name**

# %%
data.query('name.isna()')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN   1780000    530000         0
# 14244  NaN      GEN             1993   NaN         0         0     30000
#
#        other_sales  critic_score user_score rating
# 659          80000          <NA>        NaN    NaN
# 14244            0          <NA>        NaN    NaN

# %% [markdown]
# Мало данных и в других столбцах по этим строкам. Посмотрим какие игры предлагала платформа GEN в 1993:

# %%
data.query('platform == "GEN" & year_of_release == 1993')
# Out:
#                                                     name platform  \
# 659                                                  NaN      GEN
# 7885                                    Shining Force II      GEN
# 8893                             Super Street Fighter II      GEN
# 11986                            Ecco: The Tides of Time      GEN
# 12098  Street Fighter II': Special Champion Edition (...      GEN
# 12264                                  Streets of Rage 3      GEN
# 12984                                    Dynamite Headdy      GEN
# 13343                                       Beyond Oasis      GEN
# 14244                                                NaN      GEN
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 659               1993           NaN   1780000    530000         0
# 7885              1993      Strategy         0         0    190000
# 8893              1993      Fighting         0         0    150000
# ...

# %% [markdown]
# Игр несколько, поэтому название двух пропусков не определить. Удалим эти пропуски:

# %%
data = data.drop(index=[659, 14244])

# %%
data.reset_index(drop=True, inplace=True) #обновим индексы в исходном датафрейме без оставления старых индексов

# %% [markdown]
# **Пропуски в столбце year_of_release**

# %%
data1 = data.query('year_of_release.isna()')
data1
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2             <NA>
# 377                     FIFA Soccer 2004      PS2             <NA>
# 456           LEGO Batman: The Videogame      Wii             <NA>
# 475           wwe Smackdown vs. Raw 2006      PS2             <NA>
# 609                       Space Invaders     2600             <NA>
# ...                                  ...      ...              ...
# 16370  PDC World Championship Darts 2008      PSP             <NA>
# 16402                      Freaky Flyers       GC             <NA>
# 16445                          Inversion       PC             <NA>
# 16455        Hakuouki: Shinsengumi Kitan      PS3             <NA>
# 16519                       Virtua Quest       GC             <NA>
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports   4260000    260000     10000       710000            94
# ...

# %%
data = data.query('~year_of_release.isna()')
data.reset_index(drop=True, inplace=True)
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16438  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16439               LMA Manager 2007     X360             2006        Sports
# 16440        Haitaka no Psychedelica      PSV             2016     Adventure
# 16441               Spirits & Spells      GBA             2003      Platform
# 16442            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# **Пропуски в столбце genre**
#
# Пропуски в столбце genre соответствуют двум пропускам по столбцу name (индексы 659, 14244), восстановить их без названия игры нельзя, они были удалены одновременно с пропусками в столбце name.

# %% [markdown]
# **Пропуски в столбце critic_score**

# %% [markdown]
# Оценку критиков по игре можем заполнить средней оценкой той же игры на других платформах. Хотя конечно реализации игр на разных платформах могут иметь отличные оценки. Учтем, что для успешного заполнения необходимо наличие хотя бы одной оценки критика на одной из платформ.

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6676
# dtype: int64

# %% [markdown]
# Число проведенных замен 8576 - 7615 = 961. Остальные значения оставим как есть,  потому что их процент довольно большой

# %% [markdown]
# **Пропуски в столбце user_score**

# %% [markdown]
# Аббревиатура 'tbd' в столбце с оценкой пользователей - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято.

# %%
data.query('user_score == "tbd"').shape[0] #Количество значений tbd
# Out:
# 2376

# %%
data.query('user_score == "tbd"').head(10) #смотрим некоторые записи со значением tbd
# Out:
#                                 name platform  year_of_release       genre  \
# 119                    Zumba Fitness      Wii             2010      Sports
# 300   Namco Museum: 50th Anniversary      PS2             2005        Misc
# 516                  Zumba Fitness 2      Wii             2011      Sports
# 639                     uDraw Studio      Wii             2010        Misc
# 709                  Just Dance Kids      Wii             2010        Misc
# 716        Dance Dance Revolution X2      PS2             2009  Simulation
# 810                  The Incredibles      GBA             2004      Action
# 870    Who wants to be a millionaire       PC             1999        Misc
# 1036                   Tetris Worlds      GBA             2001      Puzzle
# 1037                Imagine: Teacher       DS             2008  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# ...

# %% [markdown]
# Из предоставленных данных оценку пользователей можно спрогнозировать только ориентируясь по оценкам пользователей о той же игре, но на других платформах.

# %% [markdown]
# Как и в случае с оценкой критиков будем назначать пользовательскую оценку в случае наличия хотя бы одной оценки на какой-либо из платформ. Если будет несколько оценок по разным платформам - будем считать среднее.

# %% [markdown]
# Из предоставленных данных оценку пользователей можно спрогнозировать только ориентируясь по оценкам пользователей о той же игре, но на других платформах.

# %% [markdown]
# **Пропуски в столбце rating**

# %%
data['rating'].nunique()
# Out:
# 8

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Entertainment Software Rating Board - негосударственная организация, основное направление деятельности — принятие и определение рейтингов для компьютерных видеоигр и другого развлекательного программного обеспечения в США и Канаде.
#
# «EC» («Early childhood») — «Для детей младшего возраста»: Игра подходит для детей от 3 лет и старше и не содержит материалов, которые родители могли бы счесть неподходящими. Игры, получившие данный рейтинг, изначально разрабатываются для детей и обычно представляют собой развивающие игры. Некоторые усложнённые развивающие игры могут иметь рейтинг «E».
#
# «E» («Everyone») — «Для всех»: Содержание вполне подходит для возрастной категории старше 6 лет; такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера.
#
# «E10+» («Everyone 10 and older») — «Для всех старше 10 лет»: Возрастная категория — от 10 лет. Проекты с данным рейтингом могут содержать немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены.
#
# «T» («Teen») — «Подросткам 13—19 лет»: Игра подходит для подростков старше 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.
#
# «M» («Mature») — «От 17 лет»: Материалы игры не подходят для возрастной категории младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории.
#
# «AO» («Adults Only 18+») — «Только для взрослых»: Содержание игры только для взрослых. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением.
#
# «K-A» for Kids to Adults: игры, которые содержат контент, подходящий для любой аудитории.
#
# «RP» ( «Rating Pending»») — «Рейтинг ожидается»

# %% [markdown]
# Посмотрим какие игры имеют рейтинг (кроме значения RP) и попробуем заполнить пропуски. Рейтинг RP не учитываем, потому что он не несет информации о реальном рейтинге, а лишь говорит о том, что рейтингпока ожидается. Возможно в базе уже есть та же игра, но на другой платформе, и с уже назначенным рейтингом.

# %%
data1 = data.query('rating!="RP" and ~rating.isna()')[['name', 'rating']]
data1
# Out:
#                                 name rating
# 0                         Wii Sports      E
# 2                     Mario Kart Wii      E
# 3                  Wii Sports Resort      E
# 6              New Super Mario Bros.      E
# 7                           Wii Play      E
# ...                              ...    ...
# 16425               Bust-A-Move 3000      E
# 16426               Mega Brain Boost      E
# 16430        STORM: Frontline Nation   E10+
# 16432                       Plushees      E
# 16434  Men in Black II: Alien Escape      T
#
# [9766 rows x 2 columns]

# %% [markdown]
# Проверим на дубликаты:

# %%
data1.duplicated().sum()
# Out:
# 3597

# %% [markdown]
# Удалим дубликаты, что оставить только уникальные значения для дальнейшего возможного заполнения пропусков:

# %%
data1 = data1.drop_duplicates()
data1
# Out:
#                           name rating
# 0                   Wii Sports      E
# 2               Mario Kart Wii      E
# 3            Wii Sports Resort      E
# 6        New Super Mario Bros.      E
# 7                     Wii Play      E
# ...                        ...    ...
# 16424                   Breach      T
# 16425         Bust-A-Move 3000      E
# 16426         Mega Brain Boost      E
# 16430  STORM: Frontline Nation   E10+
# 16432                 Plushees      E
#
# [6169 rows x 2 columns]

# %% [markdown]
# Переназначим индекс:

# %%
data1.reset_index(drop=True, inplace=True)
data1
# Out:
#                          name rating
# 0                  Wii Sports      E
# 1              Mario Kart Wii      E
# 2           Wii Sports Resort      E
# 3       New Super Mario Bros.      E
# 4                    Wii Play      E
# ...                       ...    ...
# 6164                   Breach      T
# 6165         Bust-A-Move 3000      E
# 6166         Mega Brain Boost      E
# 6167  STORM: Frontline Nation   E10+
# 6168                 Plushees      E
#
# [6169 rows x 2 columns]

# %% [markdown]
# Теперь, заполним рейтинг игры с пропуском, если ее название присутствует в data1:

# %%
for i in range(len(data1)):
    data.loc[(data['name'] == data1['name'][i]) & \
             (~data['rating'].isin(['E', 'M', 'T', 'E10+', 'K-A', 'AO', 'EC'])), 'rating'] = data1['rating'][i]

# %%
data['rating'].isna().sum()
# Out:
# 6259

# %% [markdown]
# 6724 - 6259 = 465 пропусков устранили

# %%
data.isna().sum() #итоговое число пропусков
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6259
# dtype: int64

# %% [markdown]
# ### Суммарные продажи по всем регионам.

# %%
data['sum_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16438  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16439               LMA Manager 2007     X360             2006        Sports
# 16440        Haitaka no Psychedelica      PSV             2016     Adventure
# 16441               Spirits & Spells      GBA             2003      Platform
# 16442            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### Выводы по шагу 2
#
# - изменяли названия всех столбцов и названия значений в столбцах (name и genre) и проверяли наличие дубликатов;
#
# - преобразовывали данные к нужному типу (столбцы year_of_release, na_sales, eu_sales, jp_sales, other_sales, critic_score, rating). Вместо float64(6),object(5) получили Int64(2), float64(2), int64(5), object(3);
#
# - обработывали пропуски: удалили все пропуски в столбцах name (они же все пропуски в столбце genre), так как их процент ничтожно мал, удалили все пропуски в столбце year_of_release, так как их процент невелик, восстановили 465 пропусков в столбце rating (остальные оставили как есть), пропуски в остальных столбцах оставили как есть;
#
# - описывали причины пропусков: основная часть пропусков находится в столбцах critic_score, user_score, rating (51%, 40 и 40% сооветственно). Примерно одинаковый процент пропусков говорит о том, что скорее всего произошел программный сбой, например, сбой синхронизации с базами данных рейтинговых сайтов, также часть игр может иметь рейтинг другой организации, а часть игр выпущены очень давно и поэтому не имеют рейтинга;
#
# - добавили новый столбец с глобальными продажами sum_sales.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы.

# %%
(
    data
        .groupby('year_of_release')['name'].count()
        .plot(kind='bar', grid=True, figsize=(12, 8))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
data.duplicated(subset=['name', 'year_of_release']).sum() #число дубликатов
# Out:
# 4248

# %%
data1 = data.drop_duplicates(subset=['name', 'year_of_release'], keep='first')

# %%
(
    data1
        .groupby('year_of_release')['name'].count()
        .plot(kind='bar', grid=True, figsize=(10, 6), \
              title='Истинное количество игр по годам', xlabel = 'Год выпуска', ylabel = 'Число игр, шт')
)
# Out:
# <AxesSubplot:title={'center':'Истинное количество игр по годам'}, xlabel='Год выпуска', ylabel='Число игр, шт'>

# %%
(
    data1
        .groupby('year_of_release')['na_sales'].sum()
        .plot(kind='bar', grid=True, figsize=(10, 6), \
              title='Число продаж игр по годам в Северной Америке', xlabel = 'Год выпуска', \
              ylim=[0, 2.6e8], ylabel = 'Суммарные продажи, шт')
)
# Out:
# <AxesSubplot:title={'center':'Число продаж игр по годам в Северной Америке'}, xlabel='Год выпуска', ylabel='Суммарные продажи, шт'>

# %% [markdown]
# Корреляция налицо.

# %% [markdown]
#    В США период с конца 1970-х до ранних 1980-х получил название — «Золотая эра видеоигр» (именно тогда рождалось огромное количество концепций и идей, которые двигали индустрию следующий десяток лет), США готовились к худшему. Многие, в надежде, что бизнес продолжит расти, открывали огромные аркадные комплексы: например Castle Park в Риверсайде, Калифорния. Многие из таких комплексов открывались в начале 1980-х, когда индустрия была на пике развития, а потом разорились почти мгновенно, лишившись основного источника игр – Atari. Эта же судьба постигла многих дистрибьюторов и другие корпорации завязанных на игровую индустрию. В 1983 году индустрия общим объёмом 3.2 млрд. долларов рухнула до 100 млн. долларов.
# Этого не видно на последнем графике, но на графике с числом игр по годам отчетливо виден спад с 1982-1983 гг.
#     После выхода PlayStation One и других представителей 5 поколения во второй половине 1990-х, 3D начало победоносное шествие по всем жанрам и платформам. С масштабами игр стали расти и бюджеты, а студии требовали всё больше квалифицированных кадров, что повышало зарплаты и привлекательность видеоигр для многих талантливых людей. На графиках видим увеличение подъем продаж и числа игр в период 1995 - 1996 гг.
#     ОДним из самых насыщенных оказался 2001 год, когда вышло наибольшее количество игр на разных платформах, отобравших у конкурентов большинство наград. Благодаря этим релизам, а также выходу приставок шестого поколения, игровая индустрия официально перешла на новый уровень, что видно по всплеску продаж и числу игр в 2001-2002 гг.
#     Начиная с 2008 США на всех парах вкатились в кризис и поделились этим достижением со всем миром. Например, Redstone Inc. и её подопечная – Midway Games. В декабре 2008, когда кризис лютовал во всю, 87% акций, которые оценивались в 70.000.000, были проданы в одни руки всего за 100.000 по курсу 0.0012 за штуку. Electronic Arts пережила кризис так «успешно», что ещё в 2012 году убытки составляли 286 млн., а первую прибыль посчитали только в 2014 — 490 млн. А ведь EA была самым крупным издателем в мире. Такое положение дел было характерно, практически, для всей индустрии: акции Activision Blizzard, Take Two, THQ, Gamestop and Nintendo провалились. THQ после такого удара уже не оправилась и в 2012 году обанкротилась.
#
# Использованные источники информации:
#
#     https://stopgame.ru/blogs/topic/89367/vsemirnaya_istoriya_igrovoy_industrii
#
#     https://cyberpedia.su/6xe0a1.html
#
#     https://www.overclockers.ua/games/games-2001/

# %% [markdown]
# Пик разработки игр приходится на 2008 и 2009 годы. Если визуально, то до 1994 года выпускалось не более 100 игр в год, поэтому  значения за период 1980-1993 гг. не так важны для анализа.

# %% [markdown]
# Посчитаем более точно с помощью диаграммы размаха:

# %%
data.boxplot(column=['year_of_release'])
# Out:
# <AxesSubplot:>

# %%
data['year_of_release'].describe()
# Out:
# count    16443.000000
# mean      2006.485921
# std          5.875546
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: year_of_release, dtype: float64

# %% [markdown]
# Межквартильный размах: 2010 - 2003 = 7. Полтора интервала: 7 * 1.5 = 10.5.
# Выбросами будем считать все, что ниже 2003 - 10.5 = 1992.5, т.е. все данные по играм до 1993 не так важны.

# %% [markdown]
# ### Изменение продаж по платформам. Платформы с наибольшими суммарными продажами. Сроки развития новых и исчезновения старых платформ.

# %%
data['platform'].nunique() #всего платформ
# Out:
# 31

# %% [markdown]
# Платформы с наибольшим суммарным числом продаж:

# %%
(
    data
        .groupby('platform')['sum_sales']
        .sum()
        .sort_values(ascending=False)
        .head(6)
)
# Out:
# platform
# PS2     1233559992
# X360     961239999
# PS3      931329995
# Wii      891179997
# DS       802780000
# PS       727579994
# Name: sum_sales, dtype: int64

# %% [markdown]
# Распределения по годам

# %%
data1 = (
    data
        .pivot_table(index='platform', values='sum_sales', aggfunc='sum')
        .sort_values('sum_sales', ascending=False)
        .index[:6].tolist()
)

for i in data1:
    (
    data
        .query('platform == @i')
        .pivot_table(columns='year_of_release', values='sum_sales', aggfunc='sum')
        .plot(kind='bar', grid=True, title= i, xlabel='Годы выпуска', ylabel='Число игр, шт')
)

# %%
data.query('platform=="DS" and year_of_release==1985')
# Out:
#                                       name platform  year_of_release   genre  \
# 15704  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 15704         0         0     20000            0          <NA>        NaN
#
#       rating  sum_sales
# 15704    NaN      20000

# %% [markdown]
# Платформа вышда в свет в 2004 году, поэтому это аномалия - удалим ее и обновим индексы датасета:

# %%
data = data.drop(index=data.query('platform=="DS" and year_of_release==1985').index)
data.reset_index(drop=True, inplace=True)
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16437  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16438               LMA Manager 2007     X360             2006        Sports
# 16439        Haitaka no Psychedelica      PSV             2016     Adventure
# 16440               Spirits & Spells      GBA             2003      Platform
# 16441            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# После лучшего года по продажам платформы исчезают в течение 5-6 лет.
# От 4 до 6 лет требуется платформам для достижения пика своего развития.
# В целом платформы сущетвуют около 10-12 лет. Время нахождения на пике популярности - в течение 1 года.

# %% [markdown]
# ### Актуальный период анализа платформ для построения прогноза на следующий год.

# %% [markdown]
# Актуальный период - это скорее всего временной промежуток около 6 лет, когда можно отследить на каком этапе развития находится платформа.

# %% [markdown]
# ### Фильтрация данных по актуальному периоду.

# %% [markdown]
# Сделаем срез с 2014 по 2016 гг.:

# %%
data_from_2014 = data.query('year_of_release >= 2014')

# %% [markdown]
# ### Платформы, лидирующие по продажам, динамика роста.  Потенциально прибыльные платформы.

# %%
data_from_2014['platform'].nunique() #всего платформ осталось после отсеивания неактуальных
# Out:
# 10

# %%
data1 = (
    data_from_2014
        .groupby('platform')['sum_sales']
        .sum()
        .sort_values(ascending=False)
        .head()
)
data1 #платформы - лидеры продаж
# Out:
# platform
# PS4     288149997
# XOne    140359999
# 3DS      86680000
# PS3      68179999
# X360     48220000
# Name: sum_sales, dtype: int64

# %% [markdown]
# Приведем столбчатые диаграммы для анализа:

# %%
for i in data1.index:
    (
    data_from_2014
        .query('platform == @i')
        .pivot_table(columns='year_of_release', values='sum_sales', aggfunc='sum')
        .plot(ylim=[0, 1.5e8], kind='bar', grid=True, title= i, xlabel='Годы выпуска', ylabel='Объем продаж игр, шт')
)

# %% [markdown]
# По всем платформам наблюдается спад продаж, но среди них можно выделить платформы, которые имеют больший объем продаж: PS4, XOne, 3DS.

# %% [markdown]
# Выбираем 3 потенцильно прибыльные платформы: PS4, XOne и 3DS.

# %% [markdown]
# ### График «ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %%
# делаем срезы по платформам-лидерам
s1 = data_from_2014.query('platform=="PS4"')['sum_sales'] 
s2 = data_from_2014.query('platform=="XOne"')['sum_sales']
s3 = data_from_2014.query('platform=="3DS"')['sum_sales']

# формируем датафрейм
df = pd.concat([s1, s2, s3], axis=1)

# переименовываем названия столбцов
df.columns = ['PS4', 'XOne', '3DS']

# строим ящики с усами в одном окне: 1 - в приближении, 2 - в общем виде со всеми выбросами
df.boxplot(column=['PS4', 'XOne', '3DS']) 
plt.ylim(0, 0.175e7) 
plt.show()
df.boxplot(column=['PS4', 'XOne', '3DS'])
plt.ylim(0, 1.6e7)
# Out:
# (0.0, 16000000.0)

# %%
data_from_2014.query('platform=="PS4"')['sum_sales'].describe()
# Out:
# count    3.760000e+02
# mean     7.663564e+05
# std      1.614969e+06
# min      1.000000e+04
# 25%      5.750000e+04
# 50%      1.850000e+05
# 75%      6.900000e+05
# max      1.463000e+07
# Name: sum_sales, dtype: float64

# %%
data_from_2014.query('platform=="XOne"')['sum_sales'].describe()
# Out:
# count    2.280000e+02
# mean     6.156140e+05
# std      1.046513e+06
# min      1.000000e+04
# 25%      5.000000e+04
# 50%      2.050000e+05
# 75%      6.325000e+05
# max      7.390000e+06
# Name: sum_sales, dtype: float64

# %%
data_from_2014.query('platform=="3DS"')['sum_sales'].describe()
# Out:
# count    2.120000e+02
# mean     4.088679e+05
# std      1.188368e+06
# min      1.000000e+04
# 25%      3.000000e+04
# 50%      9.000000e+04
# 75%      2.500000e+05
# max      1.168000e+07
# Name: sum_sales, dtype: float64

# %% [markdown]
# Описание результата:
# Медианное значение глобальных продаж у платформ PS4 и XOne примерно одинаковое и составляет 185000 и 205000 соответственно. Для платформы 3DS это 90000.
# Для платформы PS4 характерно большее число продаж вне межквартильного размаха, что можно оценить по среднеквадратичному отклонению std. Есть отдельные игры с высокими продажами, которые поти в два раза выше максимальных продаж платформы XOne.
# На платформе 3DS есть игры, которые по максимальным продажам близки к играм на платформе PS4. В то же время наибольшая медиана продаж у платформы XOne.
# В целом, платформа PS4 является потенциально более прибыльной: при правильной рекламной кампании отдельных продуктов (значечния выше третьей квартили, в том числе выбросы) можно добиться существенной выручки по сравнению с другими платформами. Также практически не уступает лидеру платформа XOne.

# %% [markdown]
# ### Влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков.

# %% [markdown]
# Выберем для анализа платформу PS4

# %%
data1 = data_from_2014.query('platform=="PS4"')

# %% [markdown]
# Диаграммы рассеяния

# %%
data1.plot(x='critic_score', y='sum_sales', kind='scatter')
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='sum_sales'>

# %%
# перед построением диаграммы рассеяния для пользовательских оценок игнорируем значение 'tbd' 
data1.query('user_score != "tbd"').plot(x='user_score', y='sum_sales', kind='scatter')
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='sum_sales'>

# %% [markdown]
# Коэффициенты корреляции

# %%
(data1.query('user_score != "tbd"')['sum_sales'])\
    .corr(data1.query('user_score != "tbd"')['user_score'].astype(float))
# Out:
# -0.04013158768010921

# %% [markdown]
# Визуально по графику и по коэффициенту корреляции не наблюдается связь между продажами и оценкой пользователей.

# %%
data1['sum_sales'].corr(data1['critic_score'].astype(float))
# Out:
# 0.4026614145813875

# %% [markdown]
# Визуально по графику и по коэффициенту корреляции видна слабая прямая связь между продажами и отзывами критиков: чем лучше отзывы критиков, тем больше продажи.

# %% [markdown]
# ### Влияние отзывов критиков и пользователей на продажи игр на других платформах.

# %% [markdown]
# Платформа XOne - тот же вывод

# %%
data1 = data_from_2014.query('platform=="XOne"')

# %%
data1.query('user_score != "tbd"')['sum_sales'] \
.corr(data1.query('user_score != "tbd"')['user_score'].astype(float))
# Out:
# -0.07038392413875955

# %%
data1['sum_sales'].corr(data1['critic_score'].astype(float))
# Out:
# 0.4286769433735717

# %% [markdown]
# Платформа 3DS - помимо корреляции с оценкой критиков, есть пусть и незначительная но корреляция с оценкой пользователей.

# %%
data1 = data_from_2014.query('platform=="3DS"')

# %%
data1.query('user_score != "tbd"')['sum_sales'] \
.corr(data1.query('user_score != "tbd"')['user_score'].astype(float))
# Out:
# 0.2151932718527029

# %%
data1['sum_sales'].corr(data1['critic_score'].astype(float))
# Out:
# 0.31411749286905094

# %% [markdown]
# ### Cамые прибыльные жанры. Жанры с высокими и низкими продажами.

# %%
data_from_2014['genre'].hist(bins=30, figsize=(15, 4))
# Out:
# <AxesSubplot:>

# %%
a = data_from_2014.groupby('genre')['sum_sales'].sum().sort_values(ascending=False)
a
# Out:
# genre
# Action          199359998
# Shooter         170939999
# Sports          109479999
# Role-Playing    101440000
# Misc             37549999
# Fighting         28220000
# Racing           27520000
# Platform         18090000
# Adventure        17550000
# Simulation       13130000
# Strategy          3960000
# Puzzle            2210000
# Name: sum_sales, dtype: int64

# %% [markdown]
# Жанр action является наиболее распространенным среди игр и самым продаваемым. Но это только на первый взгляд.

# %% [markdown]
# Посмотрим соотношение среднего числа продаж на игру с определенным жанром

# %% [markdown]
# b = data['genre'].value_counts() #число игр по жанрам
# b

# %% [markdown]
# data1 = pd.merge(a, b, right_index = True, left_index = True) #объединяем в одну таблицу по индексу жанры
# data1

# %% [markdown]
# (data1['sum_sales'] / data1['genre']).sort_values(ascending=False) # находим отношение

# %%
data_from_2014.groupby('genre')['sum_sales'].mean().sort_values(ascending=False)
# Out:
# genre
# Shooter         1.335469e+06
# Sports          6.800000e+05
# Platform        4.760526e+05
# Fighting        4.703333e+05
# Role-Playing    4.590045e+05
# Racing          3.988406e+05
# Misc            3.323009e+05
# Action          3.220678e+05
# Simulation      2.984091e+05
# Puzzle          1.578571e+05
# Strategy        1.070270e+05
# Adventure       9.486486e+04
# Name: sum_sales, dtype: float64

# %% [markdown]
# Получается самым продаваемым жанром является Shooter: на одну игру выходит около 1335000 продаж. На втором месте со значительным отставанием следует жанр Sports c 680000 продаж.

# %% [markdown]
# Самыми низкими по продажам являются жанры puzzle, strategy  и adventure - у них около 158000, 107000 и 95000 продаж на игру соответственно, что минимум в 2 раза меньше продаж лидера.

# %% [markdown]
# ### Выводы по шагу 3
# - проанализировали сколько игр выпускалось в разные годы: пик разработки игр приходится на 2008 и 2009 годы. С учетом диаграммы размаха данные по играм до 1993 не так важны;
#
# - посмотрели, как менялись продажи по платформам: выбрали платформы с наибольшими суммарными продажами и построили распределение по годам. Платформы с наибольшими суммарными продажами:
# PS4     288149997
# XOne    140359999
# 3DS      86680000
#
# - новые платформы появляются за 4-6 лет (если считать период до пика их развития), старые платформы исчезают в течение 5-6 лет, считая от пика их развития;
#
# - определили актуальный период анализа развития платформ для составления прогноза на следующий год: около 3 лет и сделали срез с 2014 по 2016 гг. включительно;
#
# - выбрали несколько потенциально прибыльных платформ: PS4, XOne и 3DS. По всем платформам наблюдается спад продаж;
#
# - построили график «ящик с усами» по глобальным продажам игр в разбивке по платформам: в
# В целом, платформа PS4 является потенциально более прибыльной: при правильной рекламной кампании отдельных продуктов (значечния выше третьей квартили, в том числе выбросы) можно добиться существенной выручки по сравнению с другими платформами. Также практически не уступает лидеру платформа XOne;
#
# - посмотрели как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков: для платформы PS4 визуально по диаграмме рассеяния и по коэффициенту корреляции видна слабая прямая связь между продажами и отзывами критиков: чем лучше отзывы критиков, тем больше продажи; для платформы XOne - тот же вывод, что и для PS4; для платформы 3DS - помимо корреляции с оценкой критиков, есть пусть и незначительная но корреляция с оценкой пользователей;
#
# - посмотрели на общее распределение игр по жанрам.
#
# Самые прибыльные жанры по общему числу продаж:
#
# Action          199359998
# Shooter         170939999
# Sports          109479999
#
# Самые малопродаваемые жанры по общему числу продаж:
#
# Simulation       13130000
# Strategy          3960000
# Puzzle            2210000
#
#
# Самые прибыльные жанры по среднему числу продаж на одну игру:
#
# Shooter         1335469
# Sports           680000
# Platform         476052
#
# Самые малопродаваемые жанры по среднему числу продаж на одну игру:
#
# Puzzle          157857
# Strategy        107027
# Adventure        94864

# %% [markdown]
# ## Шаг 4. Портрет пользователя каждого региона

# %% [markdown]
# ### Топ-5 популярных платформ. Различия в долях продаж.

# %% [markdown]
# Регион NA

# %% [markdown]
# Популярность по числу продаж на платформах

# %%
data_from_2014.groupby('platform')['na_sales'].sum().sort_values(ascending=False).head()
# Out:
# platform
# PS4     98609999
# XOne    81270000
# X360    28300000
# 3DS     22640000
# PS3     22049999
# Name: na_sales, dtype: int64

# %%
data_from_2014['na_sales'].sum() # суммарное количество продаж
# Out:
# 284059998

# %% [markdown]
# Популярность по числу игр, продаваемых на платформах

# %% [markdown]
# Сначала надем и исключим дубликаты по названиям игр:

# %%
(
    data_from_2014
        .query('na_sales != 0')
        .duplicated(subset='name')
        .sum()
)
# Out:
# 511

# %%
data1 = (
    data_from_2014
        .query('na_sales != 0')
        .drop_duplicates(subset='name', keep='first')
)

# %%
(
    data1
        .groupby('platform')['name']
        .count()
        .sort_values(ascending=False)
        .head()
)
# Out:
# platform
# PS4     248
# 3DS      69
# PSV      37
# PS3      30
# WiiU     28
# Name: name, dtype: int64

# %% [markdown]
# Регион EU

# %% [markdown]
# Популярность по числу продаж на платформах

# %%
data_from_2014.groupby('platform')['eu_sales'].sum().sort_values(ascending=False).head()
# Out:
# platform
# PS4     130039998
# XOne     46249999
# PS3      25540000
# PC       17970000
# 3DS      16120000
# Name: eu_sales, dtype: int64

# %%
data_from_2014['eu_sales'].sum()
# Out:
# 270679997

# %% [markdown]
# Популярность по числу игр, продаваемых на платформах

# %% [markdown]
# Сначала надем и исключим дубликаты по названиям игр:

# %%
(
    data_from_2014
        .query('eu_sales != 0')
        .duplicated(subset='name')
        .sum()
)
# Out:
# 565

# %%
data1 = (
    data_from_2014
        .query('eu_sales != 0')
        .drop_duplicates(subset='name', keep='first')
)

# %%
(
    data1
        .groupby('platform')['name']
        .count()
        .sort_values(ascending=False)
        .head()
)
# Out:
# platform
# PS4    247
# 3DS     68
# PC      53
# PSV     40
# PS3     29
# Name: name, dtype: int64

# %% [markdown]
# Регион JP

# %% [markdown]
# Популярность по числу продаж на платформах

# %%
data_from_2014.groupby('platform')['jp_sales'].sum().sort_values(ascending=False).head(7)
# Out:
# platform
# 3DS     44240000
# PS4     15020000
# PSV     14540000
# PS3     11220000
# WiiU     7310000
# PSP       360000
# XOne      320000
# Name: jp_sales, dtype: int64

# %%
data_from_2014['jp_sales'].sum()
# Out:
# 93090000

# %% [markdown]
# Популярность по числу игр, продаваемых на платформах

# %% [markdown]
# Сначала надем и исключим дубликаты по названиям игр:

# %%
(
    data_from_2014
        .query('jp_sales != 0')
        .duplicated(subset='name')
        .sum()
)
# Out:
# 194

# %%
data1 = (
    data_from_2014
        .query('jp_sales != 0')
        .drop_duplicates(subset='name', keep='first')
)

# %%
(
    data1
        .groupby('platform')['name']
        .count()
        .sort_values(ascending=False)
        .head()
)
# Out:
# platform
# PSV     223
# PS4     185
# 3DS     164
# PS3      58
# WiiU     28
# Name: name, dtype: int64

# %% [markdown]
# Самый играющий регион - Северная Америка (> 284 млн продаж), самый неиграющий - Япония (> 93 млн продаж).
# Самая популярная платформа:
# - Северная Америка - PS4 (98609999) , XOne (81270000) (по числу продаж) и PS4 (248), 3DS (69) (по числу продаваемых игр),
# - Европа - PS4 (130039998), XOne (46249999) (по числу продаж) и PS4 (247), 3DS (68) (по числу продаваемых игр),
# - Япония - 3DS (44240000), PS4 (15020000), PSV (14540000) (по числу продаж), PSV (223), PS4 (185), 3DS (164) (по числу продаваемых игр).

# %% [markdown]
# ### Топ-5 популярных жанров.

# %% [markdown]
# Регион NA

# %% [markdown]
# Популярность по числу продаж

# %%
data_from_2014.groupby('genre')['na_sales'].sum().sort_values(ascending=False).head()
# Out:
# genre
# Shooter         79020000
# Action          72529999
# Sports          46130000
# Role-Playing    33470000
# Misc            15049999
# Name: na_sales, dtype: int64

# %% [markdown]
# Популярность по числу продаваемых игр конкретного жанра

# %% [markdown]
# Сначала надем и исключим дубликаты по названиям игр:

# %%
(
    data_from_2014
        .query('na_sales != 0')
        .duplicated(subset='name')
        .sum()
)
# Out:
# 511

# %%
data1 = (
    data_from_2014
        .query('na_sales != 0')
        .drop_duplicates(subset='name', keep='first')
)

# %%
(
    data1
        .groupby('genre')['name']
        .count()
        .sort_values(ascending=False)
        .head()
)
# Out:
# genre
# Action          152
# Role-Playing     81
# Shooter          50
# Sports           39
# Adventure        30
# Name: name, dtype: int64

# %% [markdown]
# Регион EU

# %% [markdown]
# Популярность по числу продаж

# %%
data_from_2014.groupby('genre')['eu_sales'].sum().sort_values(ascending=False).head(7)
# Out:
# genre
# Action          74679999
# Shooter         65519999
# Sports          45729999
# Role-Playing    28170000
# Racing          14130000
# Misc            12860000
# Simulation       7300000
# Name: eu_sales, dtype: int64

# %% [markdown]
# Популярность по числу продаваемыых игр конкретного жанра

# %% [markdown]
# Сначала надем и исключим дубликаты по названиям игр:

# %%
(
    data_from_2014
        .query('eu_sales != 0')
        .duplicated(subset='name')
        .sum()
)
# Out:
# 565

# %%
data1 = (
    data_from_2014
        .query('eu_sales != 0')
        .drop_duplicates(subset='name', keep='first')
)

# %%
(
    data1
        .groupby('genre')['name']
        .count()
        .sort_values(ascending=False)
        .head()
)
# Out:
# genre
# Action          167
# Role-Playing     78
# Shooter          45
# Sports           42
# Adventure        31
# Name: name, dtype: int64

# %% [markdown]
# Регион JP

# %% [markdown]
# Популярность по числу продаж

# %%
data_from_2014.groupby('genre')['jp_sales'].sum().sort_values(ascending=False).head(7)
# Out:
# genre
# Role-Playing    31160000
# Action          29580000
# Fighting         6370000
# Misc             5610000
# Shooter          4870000
# Adventure        3600000
# Sports           3260000
# Name: jp_sales, dtype: int64

# %% [markdown]
# Популярность по числу продаваемыых игр конкретного жанра

# %% [markdown]
# Сначала надем и исключим дубликаты по названиям игр:

# %%
(
    data_from_2014
        .query('jp_sales != 0')
        .duplicated(subset='name')
        .sum()
)
# Out:
# 194

# %%
data1 = (
    data_from_2014
        .query('jp_sales != 0')
        .drop_duplicates(subset='name', keep='first')
)

# %%
(
    data1
        .groupby('genre')['name']
        .count()
        .sort_values(ascending=False)
        .head()
)
# Out:
# genre
# Action          243
# Role-Playing    133
# Adventure       101
# Misc             52
# Fighting         31
# Name: name, dtype: int64

# %% [markdown]
# **Выводы по популярности жанров игр:**
# - Северная Америка - Shooter (79020000), Action (72529999), Sports (46130000) (по числу продаж) и Action (152), Role-Playing (81), Shooter (50), Sports (39) (по числу продаваемых игр конкретного жанра),
# - Европа - Action (74679999), Shooter (65519999), Sports (45729999), Role-Playing (28170000) (по числу продаж) и Action (167), Role-Playing (78), Shooter (45), Sports (42) (по числу продаваемых игр конкретного жанра),
# - Япония - Role-playing (31160000), Action (29580000) (по числу продаж) и Action (243), Role-Playing    (133), Adventure (101) (по числу продаваемых игр).
#
# Американцы и европейцы схожи по большинству предпочитаемых жанров в отличие от японцев.

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи в отдельном регионе.

# %% [markdown]
# Для анализа оценим корреляцию между категориальными переменными в столбце rating и числом продаж в разных регионах.

# %%
data_from_2014['rating'].unique()
# Out:
# array([nan, 'M', 'E', 'T', 'E10+'], dtype=object)

# %% [markdown]
# Переведем категориальные переменные в числовой тип для расчета коэффициента корреляции. Для этого назначим числа категориальным переменным в зависимости от степени ограничения контента: чем больше ограничений тем больше число:
# 'E' - 1, 'E10+' - 2, 'T' - 3, 'M' - 4.

# %%
data_from_2014.loc[:, 'rating'] = data_from_2014['rating'].replace(['E', 'E10+', 'T', 'M'], [1, 2, 3, 4])
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
data_from_2014.plot(x='rating', y='na_sales', kind='scatter')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='na_sales'>

# %% [markdown]
# Посчитаем объемы продаж по категориям:

# %%
data_from_2014.pivot_table(columns='rating', values='na_sales', aggfunc='sum')
# Out:
# rating         1.0       2.0       3.0        4.0
# na_sales  50810000  34560000  40279999  103440000

# %%
data_from_2014.plot(x='rating', y='eu_sales', kind='scatter')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='eu_sales'>

# %% [markdown]
# Посчитаем объемы продаж по категориям:

# %%
data_from_2014.pivot_table(columns='rating', values='eu_sales', aggfunc='sum')
# Out:
# rating         1.0       2.0       3.0        4.0
# eu_sales  58319999  27510000  35329999  100989999

# %%
data_from_2014.plot(x='rating', y='jp_sales', kind='scatter')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='jp_sales'>

# %% [markdown]
# Посчитаем объемы продаж по категориям:

# %%
data_from_2014.pivot_table(columns='rating', values='jp_sales', aggfunc='sum')
# Out:
# rating        1.0      2.0       3.0      4.0
# jp_sales  8980000  4770000  16280000  8550000

# %% [markdown]
# В Северной Америке и Европе наблюдается схожее распределение объема продаж в зависимости от категорий, причем вдвое большие продажи характерны для категории 'M', на что можно обратить внимание.
#
# В Японии распределение объемов продаж по категориям отлично и вдвое большая доля продаж характерна для категории 'T'.

# %% [markdown]
# ### Выводы по шагу 4

# %% [markdown]
# **Выводы по популярности платформ:**
#
# Самый играющий регион - Северная Америка (> 284 млн продаж), самый неиграющий - Япония (> 93 млн продаж).
# Самая популярная платформа:
# - Северная Америка - PS4 (98609999) , XOne (81270000) (по числу продаж) и PS4 (248), 3DS (69) (по числу продаваемых игр),
# - Европа - PS4 (130039998), XOne (46249999) (по числу продаж) и PS4 (247), 3DS (68) (по числу продаваемых игр),
# - Япония - 3DS (44240000), PS4 (15020000), PSV (14540000) (по числу продаж), PSV (223), PS4 (185), 3DS (164) (по числу продаваемых игр).
#
# С учетом платформ- лидеров, **рекомендации по выбору платформы следующие**:
#
# - Северная Америка - PS4
# - Европа - PS4
# - Япония - PS4, 3DS
#
#
# **Выводы по популярности жанров игр:**
#
# - Северная Америка - Shooter (79020000), Action (72529999), Sports (46130000) (по числу продаж) и Action (152), Role-Playing (81), Shooter (50), Sports (39) (по числу продаваемых игр конкретного жанра),
# - Европа - Action (74679999), Shooter (65519999), Sports (45729999), Role-Playing (28170000) (по числу продаж) и Action (167), Role-Playing (78), Shooter (45), Sports (42) (по числу продаваемых игр конкретного жанра),
# - Япония - Role-playing (31160000), Action (29580000) (по числу продаж) и Action (243), Role-Playing    (133), Adventure (101) (по числу продаваемых игр).
#
# Американцы и европейцы схожи по большинству предпочитаемых жанров в отличие от японцев.
#
# С учетом информации по самым прибыльным жанрам по среднему числу продаж на игру с конкретным жанром:
# Shooter         1.335469e+06
# Sports          6.800000e+05
# Platform        4.760526e+05
# Fighting        4.703333e+05
# Role-Playing    4.590045e+05
# Racing          3.988406e+05
# Misc            3.323009e+05
# Action          3.220678e+05
#
# **рекомендации по выбору жанра следующие**:
#
# - Северная Америка - Shooter, Sports, Action, Role-Playing
# - Европа - Shooter, Sports, Action, Role-Playing
# - Япония - Role-Playing, Action
#
# Проверяли влияет ли рейтинг ESRB на продажи в отдельном регионе графическим способом: в Северной Америке и Европе наблюдается схожее распределение объема продаж в зависимости от категорий, причем вдвое большие продажи характерны для категории 'M', на что можно обратить внимание.
# В Японии распределение объемов продаж по категориям отлично и вдвое большая доля продаж характерна для категории 'T'.

# %% [markdown]
# ## Шаг 5. Проверка гипотез

# %% [markdown]
# Пороговое значение alpha примем 0.05:

# %%
alpha = 0.05

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8460
# user_score         6604
# rating             6258
# sum_sales             0
# dtype: int64

# %% [markdown]
# По пользовательским оценкам имеется большое число пропусков, поэтому оставшиеся числовые данные по оценкам будут выборками. Следовательно, используем критерий равенства среднего двух генеральных совокупностей по взятым из них выборкам.
#
# Нулевая гипотеза - средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Альтернативная гипотеза - средние пользовательские рейтинги платформ Xbox One и PC разные.

# %%
sample_1 = data.query('platform == "XOne" and ~user_score.isna() \
and user_score != "tbd"')['user_score'].astype(float) # выборка по платформе Xbox One
sample_2 = data.query('platform == "PC" and ~user_score.isna() \
and user_score != "tbd"')['user_score'].astype(float) # выборка по платформе PC 

results = st.ttest_ind(sample_1, sample_2, equal_var = False)

display('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    display("Отвергаем нулевую гипотезу")
else:
    display("Не получилось отвергнуть нулевую гипотезу")
# Out:
# 'p-значение: '
# 4.5385802963771835e-06
# 'Отвергаем нулевую гипотезу'

# %% [markdown]
# Таким образом, гипотеза о том, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые, отвергается.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# Будем использовать тот же критерий.
#
# Нулевая гипотеза - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») одинаковые
#
# Альтернативная гипотеза - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %%
sample_1 = data.query('genre == "Action" and ~user_score.isna() and user_score != "tbd"') \
['user_score'].astype(float) # выборка по жанру action
sample_2 = data.query('genre == "Sports" and ~user_score.isna() and user_score != "tbd"') \
['user_score'].astype(float) # выборка по жанру sports

results = st.ttest_ind(sample_1, sample_2, equal_var = False)

display('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    display("Отвергаем нулевую гипотезу")
else:
    display("Не получилось отвергнуть нулевую гипотезу")
# Out:
# 'p-значение: '
# 0.07751671595536253
# 'Не получилось отвергнуть нулевую гипотезу'

# %% [markdown]
# Таким образом, гипотеза о том, что средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные, отвергается.

# %% [markdown]
# ### Выводы по шагу 5
# - Гипотеза 1. **p-значение:** 4.5385802963771835e-06 'Отвергаем нулевую гипотезу'
#
# - Гипотеза 2. **p-значение:** 0.07751671595536253 'Не получилось отвергнуть нулевую гипотезу'
#
# Таким образом, обе гипотезы отвергаются. В ходе проверки использовали критерий равенства среднего двух генеральных совокупностей по взятым из них выборкам.
